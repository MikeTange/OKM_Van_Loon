# %% [markdown]
# # OKM Model #

# %% [markdown]
# ## Set-up ##

# %% [markdown]
# ### Imports ###

# %%
import pandas as pd
import numpy as np
import warnings

# %% [markdown]
# ### Objects ###

# %%
class recipe:
    """ a recipe """

    def __init__(self, name : str, id : str, data : pd.DataFrame) -> None:
        """ initialise an instance of recipe"""
        self.name = name
        self.id = id
        self.data = data

    def __str__(self) -> str:
        """ set the string representation of a recipe """
        return f'{self.id} {self.name}'

# %% [markdown]
# ### Functions ###

# %%
def rename_nan_columns(df, prefix="col"):
    """
    Rename DataFrame columns whose header could not be inferred, and have 'NaN' as header

    Parameters:
    - df: pandas.DataFrame
    - prefix: prefix to replace NaN column names with

    Returns:
    - DataFrame with renamed columns
    """
    df = df.copy()
    df.columns = [
        f"{prefix}{idx}" if pd.isna(col) else col.strip()
        for idx, col in enumerate(df.columns)]
    return df


def clean_dataframe(df, replace_empty_with_na=True):
    """
    Cleans a DataFrame by:
    - Stripping whitespace from string values
    - Optionally replacing empty strings with pd.NA
    - Converting column types using pandas' best-guess inference

    Parameters:
    - df: pandas.DataFrame
    - replace_empty_with_na: bool, whether to treat empty strings as missing values

    Returns:
    - Cleaned and type-inferred DataFrame
    """
    df = df.copy()

    # Strip whitespace from strings & replace commas with periods as floating points
    df = df.map(lambda x: x.replace(',', '.').strip() if isinstance(x, str) else x)

    # Optionally replace empty strings with pd.NA for better type inference
    if replace_empty_with_na:
        df.replace("", pd.NA, inplace=True)

    # Infer column types
    df = df.convert_dtypes()

    return df

# %% [markdown]
# ## Data preparation ##

# %% [markdown]
# ### Input parameters ###

# %%
bom_name = "250416 Recepten download NAV 16-4.xlsx"
bom_sheet_name = "Budget"
price_weight_name = "Input Price List + Grammage.xlsx"
price_weight_sheet_name = "PriceList"
waste_name = "Input Waste Table.xlsx"
waste_sheet_name = 'WASTE'

# %% [markdown]
# ### Required columns ###
# Price and weight data

# %%
req_cols_price_weight = ['INGREDIENT CODE', 'INGREDIENTS', 'KG']

# %% [markdown]
# Waste data

# %%
req_cols_waste = ['MEAL CODE', 'INGREDIENT CODE', 'WASTE-NAV', 'WASTE-FIN', 'WASTE-USE']

# %% [markdown]
# ### Data loading & initial validation ###

# %% [markdown]
# #### BOM ####

# %%
bom_data_raw = pd.read_excel(bom_name, sheet_name=bom_sheet_name, skiprows=1, header=None, decimal=",")

# %%
print(f'BOM ingelezen: {bom_name} || Tabblad: {bom_sheet_name}')
# Out:
# BOM ingelezen: 250416 Recepten download NAV 16-4.xlsx || Tabblad: Budget

# %% [markdown]
# #### Prices & weights ####

# %%
price_weight_data_raw = pd.read_excel(price_weight_name, sheet_name=price_weight_sheet_name, header=None)

# Drop leading empty rows
price_weight_data_trimmed = price_weight_data_raw.loc[~price_weight_data_raw.isnull().all(axis=1)].reset_index(drop=True)

# Promote the first non-empty row to header
header = price_weight_data_trimmed.iloc[0]
price_weight_data = price_weight_data_trimmed[1:]
price_weight_data.columns = header
price_weight_data = price_weight_data.reset_index(drop=True)

# Rename any columns named: "NaN"
price_weight_data = rename_nan_columns(price_weight_data)

# Check for required columns
if not all(x in price_weight_data.columns for x in req_cols_price_weight):
    print(f'Sommige essentiele kolommen missen in de prijslijst: {set(req_cols_price_weight) - set(price_weight_data.columns)}')

# Clean DataFrame values
price_weight_data = clean_dataframe(price_weight_data).astype({"INGREDIENT CODE": 'string', "INGREDIENTS": 'string'}) # fix incorrect type inferences as strings (universally applicable)

# %%
print(f'Prijs en gewicht lijst ingelezen: {price_weight_name} || Tabblad: {price_weight_sheet_name}')
# Out:
# Prijs en gewicht lijst ingelezen: Input Price List + Grammage.xlsx || Tabblad: PriceList

# %% [markdown]
# #### Waste ####

# %%
waste_data_raw = pd.read_excel(waste_name, sheet_name=waste_sheet_name, header=None)

# Drop leading empty rows
waste_data_trimmed = waste_data_raw.loc[~waste_data_raw.isnull().all(axis=1)].reset_index(drop=True)

# Promote the first non-empty row to header
header = waste_data_trimmed.iloc[0]
waste_data = waste_data_trimmed[1:]
waste_data.columns = header
df = waste_data.reset_index(drop=True)

# Rename any columns named: "NaN"
waste_data = rename_nan_columns(waste_data)

# Check for required columns
if not all(x in waste_data.columns for x in req_cols_waste):
    print(f'Sommige essentiele kolommen missen in de prijslijst: {set(req_cols_waste) - set(waste_data.columns)}')

# Clean DataFrame values
waste_data = clean_dataframe(waste_data).astype({'MEAL CODE': 'string', 'INGREDIENT CODE': 'string', 'UNITS': 'string'}) # fix incorrect type inferences as strings (universally applicable)

# %% [markdown]
# ##### Add unique id column #####

# %%
waste_data['id'] = waste_data[['MEAL CODE', 'INGREDIENT CODE']].agg('_'.join, axis=1).astype('string')

# %%
print(f'Waste lijst ingelezen: {waste_name} || Tabblad: {waste_sheet_name}')
# Out:
# Waste lijst ingelezen: Input Waste Table.xlsx || Tabblad: WASTE

# %% [markdown]
# ### Data cleaning ###

# %% [markdown]
# #### BOM ####

# %% [markdown]
# ##### Split data into recipes #####

# %%
recipes = []

for i in range(len(bom_data_raw)):
    # a new recipe starts
    if bom_data_raw[4][i] == 'Omschrijving':
        start_idx = i + 1
        recipe_name = bom_data_raw[4][i + 1]
        recipe_id = bom_data_raw[3][i + 1]

        # the recipe ends
        for j in range(i, len(bom_data_raw)):
            if bom_data_raw[3][j] == 'Kostenaandeel voor dit artikel':
                end_idx = j
                recipe_data = bom_data_raw.iloc[(i + 2):j].drop(range(8, 13), axis='columns').reset_index()
                recipe_data = recipe_data.rename(columns={0: "id_nr", 1: "nr", 2: "Niveau", 3: "hf_nr", 4: "Omschrijving", 5: "Aantal (Basis)", 6: "Basiseenheid", 7: "Materiaalkosten"})
                recipe_data = recipe_data.astype({"id_nr": str, "nr": int, "Niveau": int, "hf_nr": str, "Omschrijving": str, "Aantal (Basis)": float, "Basiseenheid": str, "Materiaalkosten": float})
                recipe_data.insert(loc=2, column="Product Naam", value=[recipe_name for i in range(len(recipe_data))])
                recipes.append(recipe(name=recipe_name, id=recipe_id, data=recipe_data))
                i += j
                break

# %% [markdown]
# ### Product master ###
# Create a product master based on the information in the BOM:
# - If an item starts with '3' --> **packaging**, else
# - If an item has a child --> **HF**, else
# - Item --> **ingredient**

# %%
product_master_dict = {}

for recipe in recipes:
    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if not item_id in product_master_dict.keys():
            if item_id.startswith('3'):
                classification = 'Verpakking'
            elif not i + 1 == len(recipe.data):
                if recipe.data['Niveau'][i + 1] > recipe.data['Niveau'][i]:
                    classification = 'Halffabrikaat'
                else:
                    classification = 'Ingredient'
            else:
                classification = 'Ingredient'
        
            product_master_dict[item_id] = [item_id, classification]

product_master = pd.DataFrame.from_dict(product_master_dict, orient='index', columns=['Nummer', 'Categorie']).reset_index(drop=True)

# %% [markdown]
# ##### Split product data by categorie #####
# Store the ids ('hf_nr') in NumPy arrays for easy and fast checking against later.

# %%
product_data_ingredient = np.array(product_master[product_master['Categorie'] == 'Ingredient']['Nummer'])
product_data_packaging = np.array(product_master[product_master['Categorie'] == 'Verpakking']['Nummer'])
product_data_HF = np.array(product_master[product_master['Categorie'] == 'Halffabrikaat']['Nummer'])

# %% [markdown]
# ## User input ##
# Get user input on what to do exactly.

# %%
# price_period = input(f'In welke van de volgende kolommen staan de nieuwe prijzen?\n{[x for x in price_weight_data.columns]}')
price_period = 'PRICE Q2'

# %% [markdown]
# ## Data validation ##
# Validating the correctness of the input data.

# %% [markdown]
# ### Ingredients ###
#
# Check if all ingredients have a new price.

# %%
ing_error_list = []

for ing in product_data_ingredient:
    subset = price_weight_data[price_weight_data['INGREDIENT CODE'] == ing].reset_index()

    if len(subset) == 1:
        try:
            price = float(subset[price_period].iloc[0])
        except ValueError:
            ing_error_list.append(f'Kan de prijs voor ingredient: "{ing}" niet lezen. Prijs: "{subset[price_period][0]}"')
    
    elif len(subset) == 0:
        ing_error_list.append(f'Ingredient "{ing}" komt niet voor in de prijslijst')

    else:
        ing_error_list.append(f'Ingredient "{ing}" komt meermaals voor in de prijslijst. Indexen: {subset["index"]}')

# %% [markdown]
# In case of no errors, force cast data type for price_period if it's not already correct.

# %%
if (price_weight_data[price_period].dtype == 'O') and (len(ing_error_list) == 0):
    price_weight_data[price_period].astype('float64')

# %% [markdown]
# ### Waste ###
# Check if all items at level 1 have waste percentages.

# %%
waste_error_list = []

for recipe in recipes:
    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]
        waste_id = f'{recipe.id}_{item_id}'

        if recipe.data['Niveau'][i] == 1:
            if not item_id in product_data_packaging: # ignore packaging
                subset = waste_data[waste_data['id'] == waste_id]

                if len(subset) == 1:
                    nav = subset['WASTE-NAV'].iloc[0]
                    fin = subset['WASTE-FIN'].iloc[0]
                    use = subset['WASTE-USE'].iloc[0]
                    try:
                        waste = float(nav) + float(fin) + float(use)
                    except ValueError:
                        waste_error_list.append(f'Kan de waste voor level 1 item: "{item_id}", voor maaltijd: "{recipe.id}" niet lezen. Waste-nav: "{nav}", Waste-fin: "{fin}", Waste-use: "{use}"')

                elif len(subset) == 0:
                    waste_error_list.append(f'Level 1 item: "{item_id}", voor maaltijd: "{recipe.id}" komt niet voor in de waste lijst')

                else:
                    waste_error_list.append(f'Level 1 item: "{item_id}", voor maaltijd: "{recipe.id}" komt meermaals voor in de waste lijst')

# %% [markdown]
# In case of no errors, force cast data types for waste columns if they're not already correct.

# %%
if (waste_data['WASTE-NAV'].dtype == 'O') and (len(waste_error_list) == 0):
    waste_data['WASTE-NAV'].astype('float64')

if (waste_data['WASTE-FIN'].dtype == 'O') and (len(waste_error_list) == 0):
    waste_data['WASTE-FIN'].astype('float64')

if (waste_data['WASTE-USE'].dtype == 'O') and (len(waste_error_list) == 0):
    waste_data['WASTE-USE'].astype('float64')

# %% [markdown]
# ### Errors feedback ###
# Give feedback to the user about data validation errors.

# %%
if (len(ing_error_list) == 0) and (len(waste_error_list)) == 0:
    print('Data validatie succesvol! Geen errors gevonden')

else:
    print('-' * 80)
    print('-' * 80)
    print('Data validatie problemen gevonden:')
    print('-' * 80)
    print('-' * 80)
    
    with pd.ExcelWriter("errors.xlsx") as writer:
        pd.DataFrame(ing_error_list, columns=['errors']).to_excel(writer, sheet_name="Ingredienten errors")
        pd.DataFrame(waste_error_list, columns=['errors']).to_excel(writer, sheet_name="Waste errors")

    if len(ing_error_list) != 0:
        print('Ingredienten errors:')
        print('-' * 80)
        for error in ing_error_list:
            print(error)
    
    if len(waste_error_list) != 0:
        print('-' * 80)
        print('Waste errors:')
        print('-' * 80)
        for error in waste_error_list:
            print(error)
    
    print('-' * 80)
    print('-' * 80)
    print('Output error file opgeslagen: errors.xlsx')
    print('-' * 80)
    print('-' * 80)
# Out:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Data validatie problemen gevonden:
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Waste errors:
# --------------------------------------------------------------------------------
# Level 1 item: "101146", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "HF710136", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "HF775241", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "HF775242", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "HF92925", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565021G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "HF710136", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "HF775241", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "HF775242", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "HF92925", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565021N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "HF765048", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "101426", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "HF755347", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "HF765047", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565022G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "HF765048", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "101426", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "HF755347", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "HF765047", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565022N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF760066", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF765050", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF760067", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF727100", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF92926", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565023G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF760066", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF765050", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF760067", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF727100", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF92926", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565023N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF760068", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF740157", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF21076", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF775245", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565024G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF760068", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF740157", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF21076", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF775245", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565024N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "HF775247", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565026G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "HF775247", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565026N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF740139", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF21077", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF760070", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF775250", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF92928", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF775251", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "159143", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565027G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF740139", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF21077", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF760070", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF775250", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF92928", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF775251", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "159143", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565027N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF710226", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF727101", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF760071", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF92929", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF765056", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565028G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF710226", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF727101", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF760071", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF92929", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF765056", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565028N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF710227", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF775253", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF21191", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF23237", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF92931", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF775254", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565029G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF710227", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF775253", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF21191", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF23237", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF92931", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF775254", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565029N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "HF740334", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "HF740141", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "HF744537", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565030G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "HF740334", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "HF740141", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "HF744537", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565030N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF710228", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF775256", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF775257", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF760072", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF775258", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "159144", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF92932", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565031G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF710228", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF775256", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF775257", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF760072", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF775258", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "159144", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF92932", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565031N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "HF740143", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "HF765053", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "HF765052", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565032G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "HF740143", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "HF765053", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "HF765052", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565032N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "HF710229", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "HF21264", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "HF21156", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "HF21157", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565033G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "HF710229", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "HF21264", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "HF21156", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "HF21157", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565033N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "HF765057", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "HF765058", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "HF720234", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565035G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "HF765057", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "HF765058", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "HF720234", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565035N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "HF710231", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "HF740146", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "HF755360", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565036G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "HF710231", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "HF740146", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "HF755360", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565036N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF740147", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF755363", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF765063", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF765064", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF725011", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF765116", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565039G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF740147", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF755363", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF765063", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF765064", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF725011", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF765116", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565039N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "101425", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "HF755365", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "HF765106", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565042G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "101425", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "HF755365", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "HF775255", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "HF765106", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565042N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF755366", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF765071", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF740150", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF23237", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF745317", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF765072", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565043G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF755366", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF765071", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF740150", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF23237", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF745317", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF765072", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565043N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF710236", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF765073", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF765074", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF92970", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565044G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF710236", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF765073", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF765074", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF92970", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565044N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF710237", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF765075", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF765076", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF765077", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF92971", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565045G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF710237", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF765075", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF765076", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF765077", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF92971", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565045N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF720245", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF775248", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF755372", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "159152", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF765081", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565047G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF720245", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF775248", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF755372", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "159152", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF765081", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565047N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "HF755373", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "HF720244", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "HF720245", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565048G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "HF755373", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "HF720244", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "HF720245", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565048N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF740795", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF720246", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF765083", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF765084", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF92976", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565050G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF740795", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF720246", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF765083", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF765084", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF92976", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565050N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF710239", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF765088", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF740155", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF765089", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF765090", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF92974", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565053G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF710239", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF765088", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF740155", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF765089", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF765090", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF92974", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565053N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF765091", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF765088", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF765093", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565054G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF765091", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF765088", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF765093", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565054N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF755347", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF720234", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF765066", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565055G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF755347", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF720234", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF765066", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565055N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF755391", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF765096", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF765079", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF21096", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF727124", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF92981", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565056G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF755391", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF765096", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF765079", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF21096", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF727124", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF92981", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565056N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "101422", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "HF21264", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "HF765101", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "HF710251", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565059G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "101422", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "HF21264", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "HF765101", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "HF710251", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565059N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "HF755401", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "HF765102", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "159152", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "HF765103", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "159130", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565060G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "HF755401", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "HF765102", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "159152", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "HF765103", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "159130", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565060N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF765104", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF740166", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF765105", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF755402", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565061G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF765104", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF740166", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF765105", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF755402", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565061N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF710248", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF755368", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF765085", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF765107", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF765108", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565062G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF710248", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF755368", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF765085", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF765107", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF765108", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565062N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "HF740167", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "HF765109", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "HF765065", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565063G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "HF740167", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "HF765109", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "HF765065", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565063N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "HF720233", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "101426", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "HF755403", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "HF765110", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "HF765098", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565064G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "HF720233", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "101426", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "HF755403", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "HF765110", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "HF765098", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565064N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "HF765111", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "HF789092", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "HF727131", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565065G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "HF765111", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "HF789092", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "HF727131", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565065N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "HF765065", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "HF740147", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "HF755363", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565066G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "HF765065", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "HF740147", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "HF755363", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565066N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "HF755405", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "HF740168", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "HF21101", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "HF765109", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565067G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "HF755405", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "HF740168", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "HF21101", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "HF765109", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565067N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565068G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565068G" komt niet voor in de waste lijst
# Level 1 item: "HF755406", voor maaltijd: "565068G" komt niet voor in de waste lijst
# Level 1 item: "HF765114", voor maaltijd: "565068G" komt niet voor in de waste lijst
# Level 1 item: "HF765115", voor maaltijd: "565068G" komt niet voor in de waste lijst
# ...
# Level 1 item: "101146", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "HF21365", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "HF740141", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "HF21362", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "HF21374", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565143G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "HF21365", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "HF740141", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "HF21362", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "HF21374", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565143N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF710248", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF21364", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF765085", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF765107", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF765108", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565144G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF710248", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF21364", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF765085", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF765107", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF765108", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565144N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "HF21367", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "HF740146", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "HF21360", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565145G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "HF21367", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "HF740146", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "HF21360", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "HF19949", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565145N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF21368", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF21083", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "HF21144", voor maaltijd: "565146G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF21368", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF21083", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "HF21144", voor maaltijd: "565146N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF765104", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF21372", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF765105", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF755402", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565147G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF765104", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF740165", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF21372", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF765105", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF755402", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565147N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF765091", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF21373", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF765093", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565148G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF765091", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF21373", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF765092", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF765093", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565148N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "HF21182", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "HF21359", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565149G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "HF21182", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "HF765124", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "HF21359", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "159148", voor maaltijd: "565149N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "HF775247", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565150G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "HF755377", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "HF740138", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "HF775247", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565150N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF760068", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF740157", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF21377", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF775244", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF775245", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565151G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF760068", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF740157", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "159142", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF21377", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF775244", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF775245", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565151N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "HF21379", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "101424", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "HF21378", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "HF21097", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565152" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "HF21379", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "101424", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "HF21378", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "HF21097", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565152G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "HF21379", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "101424", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "HF21378", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "HF21097", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565152N" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "HF21381", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "HF21079", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "HF21383", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565155" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "HF21381", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "HF21079", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "HF21383", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565155G" komt niet voor in de waste lijst
# Level 1 item: "101146", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "101147", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF21381", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF740145", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF21079", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF21383", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "159140", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF760073", voor maaltijd: "565155N" komt niet voor in de waste lijst
# Level 1 item: "HF21253", voor maaltijd: "HF21254" komt niet voor in de waste lijst
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Output error file opgeslagen: errors.xlsx
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Modeling ##

# %%
print('Starten met modeleren')
# Out:
# Starten met modeleren

# %% [markdown]
# ### Add categories ###

# %%
for recipe in recipes:
    categories = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if item_id in product_data_ingredient:
            categories.append('Ingredient')

        elif item_id in product_data_HF:
            categories.append('Halffabrikaat')

        elif item_id in product_data_packaging:
            categories.append('Verpakking')
        
        else:
            categories.append('Ongeclassificeerd')
    
    recipe.data['Categorie'] = categories

# %% [markdown]
# ### New prices ###
# From price list for ingredients & gas; 0 for packaging; and empty for HFs.

# %%
for recipe in recipes:
    new_prices = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if item_id in product_data_ingredient: # ingredients
            subset_price_df = price_weight_data[price_weight_data['INGREDIENT CODE'] == item_id]
            new_price = subset_price_df['PRICE Q2'].iloc[0]
        
        elif item_id in product_data_packaging: # packaging
            new_price = 0

        elif item_id in product_data_HF: # HFs
            new_price = None
        
        else: # unclassified
            new_price = 'Geen nieuwe prijs'
    
        new_prices.append(new_price)
        
    recipe.data['Nieuwe prijs'] = new_prices

# %% [markdown]
# ### Old prices ###
# Old costs / old quantity for ingredients & gas; 0 for packaging; and empty for HFs.

# %%
warnings.filterwarnings('ignore', category=RuntimeWarning)

for recipe in recipes:
    old_prices = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if item_id in product_data_ingredient: # ingredients
            old_price = recipe.data['Materiaalkosten'][i] / recipe.data['Aantal (Basis)'][i]
        
        elif item_id in product_data_packaging: # packaging
            old_price = 0

        elif item_id in product_data_HF: # HFs
            old_price = None

        else: # unclassified
            old_price = recipe.data['Materiaalkosten'][i] / recipe.data['Aantal (Basis)'][i]
    
        old_prices.append(old_price)
        
    recipe.data['Oude prijs'] = old_prices

# %% [markdown]
# ### Weight in kg ###
# Convert items not in kg. Items already in kg stay the same. Packaging goes to 0, regardless of the unit.

# %%
for recipe in recipes:
    weights = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if item_id in product_data_packaging: # packaging to 0
            weight = 0.0

        elif not recipe.data['Basiseenheid'][i] == 'KG':

            subset_weight_data = price_weight_data[price_weight_data['INGREDIENT CODE'] == item_id]

            if len(subset_weight_data) == 0: # no info about this item
                weight = 'Geen conversie info'
            
            elif len(subset_weight_data) == 1: # new info about this item
                weight = subset_weight_data['KG'].iloc[0] * recipe.data['Aantal (Basis)'][i]

            else:
                weight = 'Dubbele conversie info'
        
        else:
            weight = recipe.data['Aantal (Basis)'][i]

        weights.append(weight)

    recipe.data['Grammage'] = weights

# %% [markdown]
# ### Waste ###
# For items at level 1: find the waste in the waste data. For all other items, find the parent item at level 1, and take the waste from there.

# %%
for recipe in recipes:
    waste_nav_col = []
    waste_fin_col = []
    waste_use_col = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if recipe.data['Niveau'][i] == 1: # waste is only determined at level 1
            subset_waste_data = waste_data[waste_data['id'] == f'{recipe.id}_{item_id}']

            if len(subset_waste_data) == 0:
                # waste_nav = 'Geen waste info'
                # waste_fin = 'Geen waste info'
                # waste_use = 'Geen waste info'

                waste_nav = 0
                waste_fin = 0
                waste_use = 0

            elif len(subset_waste_data) == 1:
                waste_nav = subset_waste_data['WASTE-NAV'].iloc[0]
                waste_fin = subset_waste_data['WASTE-FIN'].iloc[0]
                waste_use = subset_waste_data['WASTE-USE'].iloc[0]

            else:
                waste_nav = 'Dubbele waste info'
                waste_fin = 'Dubbele waste info'
                waste_use = 'Dubbele waste info'
        
        else:
            for j in range(i, -1, -1): # loop backwards to find the closest level 1 item
                if recipe.data['Niveau'].iloc[j] == 1:

                    if recipe.data['hf_nr'].iloc[j] in product_data_HF:
                        parent_hf_id = recipe.data["hf_nr"].iloc[j]
                        subset_waste_data_parent = waste_data[waste_data['id'] == f'{recipe.id}_{parent_hf_id}']

                        if len(subset_waste_data_parent) == 0:
                            # waste_nav = 'Geen waste info'
                            # waste_fin = 'Geen waste info'
                            # waste_use = 'Geen waste info'

                            waste_nav = 0
                            waste_fin = 0
                            waste_use = 0

                        elif len(subset_waste_data_parent) == 1:
                            waste_nav = subset_waste_data_parent['WASTE-NAV'].iloc[0]
                            waste_fin = subset_waste_data_parent['WASTE-FIN'].iloc[0]
                            waste_use = subset_waste_data_parent['WASTE-USE'].iloc[0]

                        else:
                            waste_nav = 'Dubbele waste info'
                            waste_fin = 'Dubbele waste info'
                            waste_use = 'Dubbele waste info'

                    else:
                        waste_nav = 'Geen bijbehorend HF'
                        waste_fin = 'Geen bijbehorend HF'
                        waste_use = 'Geen bijbehorend HF'
                    
                    break

        waste_nav_col.append(waste_nav)
        waste_fin_col.append(waste_fin)
        waste_use_col.append(waste_use)

    recipe.data['Waste NAV'] = waste_nav_col
    recipe.data['Waste FIN'] = waste_fin_col
    recipe.data['Waste USE'] = waste_use_col

# %% [markdown]
# ### Quantities ###
# Calculate the quantities based on the known waste data.

# %%
for recipe in recipes:
    q_no_waste_col = []
    q_new_col = []

    for i in range(len(recipe.data)):
        
        try:
            q_no_waste = recipe.data['Aantal (Basis)'][i] / (1 + recipe.data['Waste NAV'][i])
        except TypeError:
            q_no_waste = 'Kan niet berekenen'

        try:
            q_new = q_no_waste * (1 + recipe.data['Waste USE'][i])
        except TypeError:
            q_new = 'Kan niet berekenen'

        q_no_waste_col.append(q_no_waste)
        q_new_col.append(q_new)

    recipe.data['Aantal (zonder waste)'] = q_no_waste_col
    recipe.data['Aantal (nieuw)'] = q_new_col

# %% [markdown]
# ### Costs ###
# Several costs are calculated:
# - new p * old q ("vvp")
# - new p * new q ("materiaalkosten")
#
# Costs are first calculated for the non-HF items, based on row-level info. Afterwards the HF item costs are calculated and inserted based on hierarchical info.

# %% [markdown]
# #### Non-HF costs ####

# %%
for recipe in recipes:
    newp_oldq_col = []
    newp_newq_col = []

    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if (item_id in product_data_ingredient) or (item_id in product_data_packaging):
            try:
                newp_oldq = recipe.data['Nieuwe prijs'][i] * recipe.data['Aantal (Basis)'][i]
                newp_newq = recipe.data['Nieuwe prijs'][i] * recipe.data['Aantal (nieuw)'][i]
            
            except TypeError: # could use the old price here as well
                newp_oldq = 'Kan niet berekenen'
                newp_newq = 'Kan niet berekenen'
        
        elif item_id in product_data_HF:
            newp_oldq = None
            newp_newq = None
        
        else:
            newp_oldq = 'Ongeclassificeerd item'
            newp_newq = 'Ongeclassificeerd item'

        newp_oldq_col.append(newp_oldq)
        newp_newq_col.append(newp_newq)

    recipe.data['Nieuwe vvp'] = newp_oldq_col
    recipe.data['Materiaalkosten (nieuw)'] = newp_newq_col

# %% [markdown]
# #### HF costs ####
# For an HF the costs are determined based on the costs of the individual ingredients which make up the HF.

# %%
for recipe in recipes:
    for i in range(len(recipe.data)):
        item_id = recipe.data['hf_nr'][i]

        if item_id in product_data_HF:

            hf_newp_oldq = 0.0
            hf_newp_newq = 0.0
            hf_oldp_oldq = 0.0

            hf_level = recipe.data['Niveau'][i]
            for j in range(i + 1, len(recipe.data)):
                if recipe.data['Niveau'][j] > hf_level:

                    try:
                        if not np.isnan(recipe.data['Nieuwe vvp'][j]):
                            hf_newp_oldq += recipe.data['Nieuwe vvp'][j]
                    except:
                        pass
                    
                    try:
                        if not np.isnan(recipe.data['Materiaalkosten (nieuw)'][j]):
                            hf_newp_newq += recipe.data['Materiaalkosten (nieuw)'][j]
                    except:
                        pass
                    
                    try:
                        if not np.isnan(recipe.data['Materiaalkosten'][j]):
                            if not recipe.data['hf_nr'][j] in product_data_HF:
                                hf_oldp_oldq += recipe.data['Materiaalkosten'][j]
                    except:
                        pass
                    
                else:
                    break
        
            recipe.data.at[i, 'Nieuwe vvp'] = hf_newp_oldq
            recipe.data.at[i, 'Materiaalkosten (nieuw)'] = hf_newp_newq
            recipe.data.at[i, 'Materiaalkosten HF (berekend)'] = hf_oldp_oldq

# %% [markdown]
# ### Deltas ###

# %%
for recipe in recipes:
    delta_q_col = []
    delta_p_col = []
    delta_cost_col = []
    fin_waste_impact_col = []

    for i in range(len(recipe.data)):

        try:
            delta_q = (recipe.data['Aantal (nieuw)'][i] - recipe.data['Aantal (Basis)'][i]) * recipe.data['Oude prijs'][i]
            delta_p = (recipe.data['Nieuwe prijs'][i] - recipe.data['Oude prijs'][i]) * recipe.data['Aantal (nieuw)'][i]
            delta_cost = recipe.data['Materiaalkosten (nieuw)'][i] - recipe.data['Materiaalkosten'][i]
            fin_waste_impact = recipe.data['Materiaalkosten (nieuw)'][i] - recipe.data['Nieuwe vvp'][i]

        except TypeError:
            delta_q = 'Kan niet berekenen'
            delta_p = 'Kan niet berekenen'
            delta_cost = 'Kan niet berekenen'
            fin_waste_impact = 'Kan niet berekenen'

        delta_q_col.append(delta_q)
        delta_p_col.append(delta_p)
        delta_cost_col.append(delta_cost)
        fin_waste_impact_col.append(fin_waste_impact)
    
    recipe.data['Delta Q'] = delta_q_col
    recipe.data['Delta prijs'] = delta_p_col
    recipe.data['Delta materiaalkosten'] = delta_cost_col
    recipe.data['Delta FIN waste'] = fin_waste_impact_col

# %%
print('Klaar met modeleren')
# Out:
# Klaar met modeleren

# %% [markdown]
# ## Output Excel file ##

# %%
print('Output file maken')
# Out:
# Output file maken

# %% [markdown]
# ### BOM ###

# %%
frames = []
for recipe in recipes:
    frames.append(recipe.data)

BOM_df = pd.concat(frames)

# %% [markdown]
# ### Excel file formatting ###
# Change column order and names. Drop a few columns.

# %%
# Reorder and drop columns
BOM_df = BOM_df[['index', 'id_nr', 'Product Naam', 'nr', 'Niveau', 'hf_nr', 'Omschrijving', 'Aantal (Basis)', 'Basiseenheid', 'Materiaalkosten', 'Categorie', 'Nieuwe prijs', 'Oude prijs',
                 'Nieuwe vvp', 'Waste NAV', 'Waste FIN', 'Waste USE', 'Aantal (zonder waste)', 'Aantal (nieuw)', 'Materiaalkosten (nieuw)', 'Delta materiaalkosten', 'Delta Q', 
                 'Delta prijs', 'Delta FIN waste', 'Grammage']]

# Rename columns
BOM_df = BOM_df.rename(columns={"index": "Index",
                                'id_nr': 'Meal ID',
                                'Product Naam': 'Meal Name',
                                'nr': 'Volgnummer',
                                'Niveau': 'Level',
                                'hf_nr': 'Ingredient ID',
                                'Omschrijving': 'Ingredient Name',
                                'Aantal (Basis)': 'Aantal (Basis) (#)',
                                'Basiseenheid': 'Eenheid (€ / KG-Stuk-Liter-Mtr)',
                                'Materiaalkosten': 'Materiaalkosten 1.0 (P BOM + Q BOM) (€)',
                                'Categorie': 'Categorie Master',
                                'Nieuwe prijs': 'Ingredientprijs p.e. (Actueel) (€)',
                                'Oude prijs': 'Ingredientprijs p.e. (BOM - Berekend) (€)',
                                'Nieuwe vvp': 'Materiaalkosten 2.0 (P actueel) (€)',
                                'Waste NAV': 'Uitval NAV (%)',
                                'Waste FIN': 'Uitval FIN (%)',
                                'Waste USE': 'Uitval USE (%)',
                                'Aantal (zonder waste)': 'Aantal uitval EXL (#)',
                                'Aantal (nieuw)': 'Aantal uitval USE (#)',
                                'Materiaalkosten (nieuw)': 'Materiaalkosten 3.0 (P actueel + Q Waste update) (€)',
                                'Delta materiaalkosten': 'Materiaalkosten (Delta 3.0 vs 1.0) (€)',
                                'Delta Q': 'Materiaalkosten (Q-effect 3.0 vs 1.0) (€)',
                                'Delta prijs': 'Materiaalkosten (P-effect 3.0 vs 1.0) (€)',
                                'Delta FIN waste': 'FIN Waste Impact Waste Update (Delta 3.0 vs 2.0) (€)',
                                'Grammage': 'Gewicht (kg)'
                                })

# %% [markdown]
# ### Save to Excel ###

# %%
with pd.ExcelWriter("Output v7 - Q2.xlsx") as writer:
    BOM_df.to_excel(writer, sheet_name="BOM")
